# %% [markdown]
# # Machine Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# The dataset is already in this repository as files, so there is no extra steps to download. What I need to do is to load the files. There are 2 files, and each contains bunch of sentences in English and French respectively. They are just plain text data.

# %%
import os
import pickle
import copy
import numpy as np

def load_data(path):
    input_file = os.path.join(path)
    with open(input_file, 'r', encoding='utf-8') as f:
        data = f.read()

    return data

# %%
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = load_data(source_path)
target_text = load_data(target_path)

# %% [markdown]
# ## Explore the Data
#
# The two datasets store bunch of sentences in different language, and that is something we don't have to explore for now. You probably already know how your data looks like when you decided to download this one. **However**, it is worthwhile to explore how complex the datasets are. The complexity could suggest how we should approach to get the right result still considering some of restrictions.
#
# `note: ` The two files exactly contains the same number of lines. Each i-th line in both files has the same meaning but expressed in different languages.

# %%
from collections import Counter

print('Dataset Brief Stats')
print('* number of unique words in English sample sentences: {}\
        [this is roughly measured/without any preprocessing]'.format(len(Counter(source_text.split()))))
print()

english_sentences = source_text.split('\n')
print('* English sentences')
print('\t- number of sentences: {}'.format(len(english_sentences)))
print('\t- avg. number of words in a sentence: {}'.format(np.average([len(sentence.split()) for sentence in english_sentences])))

french_sentences = target_text.split('\n')
print('* French sentences')
print('\t- number of sentences: {} [data integrity check / should have the same number]'.format(len(french_sentences)))
print('\t- avg. number of words in a sentence: {}'.format(np.average([len(sentence.split()) for sentence in french_sentences])))
print()

sample_sentence_range = (0, 5)
side_by_side_sentences = list(zip(english_sentences, french_sentences))[sample_sentence_range[0]:sample_sentence_range[1]]
print('* Sample sentences range from {} to {}'.format(sample_sentence_range[0], sample_sentence_range[1]))

for index, sentence in enumerate(side_by_side_sentences):
    en_sent, fr_sent = sentence
    print('[{}-th] sentence'.format(index+1))
    print('\tEN: {}'.format(en_sent))
    print('\tFR: {}'.format(fr_sent))
    print()
# Out:
# Dataset Brief Stats
# * number of unique words in English sample sentences: 227        [this is roughly measured/without any preprocessing]
#
# * English sentences
# 	- number of sentences: 137861
# 	- avg. number of words in a sentence: 13.225277634719028
# * French sentences
# 	- number of sentences: 137861 [data integrity check / should have the same number]
# 	- avg. number of words in a sentence: 14.226612312401622
#
# * Sample sentences range from 0 to 5
# [1-th] sentence
# 	EN: new jersey is sometimes quiet during autumn , and it is snowy in april .
# 	FR: new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
#
# [2-th] sentence
# 	EN: the united states is usually chilly during july , and it is usually freezing in november .
# 	FR: les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
#
# [3-th] sentence
# 	EN: california is usually quiet during march , and it is usually hot in june .
# 	FR: california est généralement calme en mars , et il est généralement chaud en juin .
#
# [4-th] sentence
# 	EN: the united states is sometimes mild during june , and it is cold in september .
# 	FR: les états-unis est parfois légère en juin , et il fait froid en septembre .
#
# [5-th] sentence
# 	EN: your least liked fruit is the grape , but my least liked is the apple .
# 	FR: votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .

# %% [markdown]
# ## Preprocessing
#
# Here are brief overview what steps will be done in this section
#
# - **create lookup tables**
#   - create two mapping tables
#       - (key, value) == (unique word string, its unique index)     - (1)
#       - (key, value) == (its unique index, unique word string)     - (2)
#       - (1) is used in the next step, and (2) is used later for prediction step
#
#
# - **text to word ids**
#   - convert each string word in the list of sentences to the index
#   - (1) is used for converting process
#
#
# - **save the pre-processed data**
#   - create two (1) mapping tables for English and French
#   - using the mapping tables, replace strings in the original source and target dataset with indicies
#
# ### Create Lookup Tables
#
# As mentioned breifly, I am going to implement a function to create lookup tables. Since every models are mathmatically represented, the input and the output(prediction) should also be represented as numbers. That is why this step is necessary for NLP problem because human readable text is not machine readable. This function takes a list of sentences and returns two mapping tables (dictionary data type). Along with the list of sentences, there are special tokens, `<PAD>`, `<EOS>`, `<UNK>`, and `<GO>` to be added in the mapping tables.
#
# - (key, value) == (unique word string, its unique index)     - (1)
# - (key, value) == (its unique index, unique word string)     - (2)
#
# (1) will be used in the next step, `test to word ids`, to find a match between word and its index. (2) is not used in pre-processing step, but (2) will be used later. After making a prediction, the sequences of words in the output sentence will be represented as their indicies. The predicted output is machine readable but not human readable. That is why we need (2) to convert each indicies of words back into human readable words in string.
#
# #### References
# - [Why special tokens?](https://datascience.stackexchange.com/questions/26947/why-do-we-need-to-add-start-s-end-s-symbols-when-using-recurrent-neural-n)
# - [Python `enumerate`](https://docs.python.org/3/library/functions.html#enumerate)

# %%
CODES = {'<PAD>': 0, '<EOS>': 1, '<UNK>': 2, '<GO>': 3 }

def create_lookup_tables(text):
    # make a list of unique words
    vocab = set(text.split())

    # (1)
    # starts with the special tokens
    vocab_to_int = copy.copy(CODES)

    # the index (v_i) will starts from 4 (the 2nd arg in enumerate() specifies the starting index)
    # since vocab_to_int already contains special tokens
    for v_i, v in enumerate(vocab, len(CODES)):
        vocab_to_int[v] = v_i

    # (2)
    int_to_vocab = {v_i: v for v, v_i in vocab_to_int.items()}

    return vocab_to_int, int_to_vocab

# %% [markdown]
# ### Text to Word Ids

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
        1st, 2nd args: raw string text to be converted
        3rd, 4th args: lookup tables for 1st and 2nd args respectively
    
        return: A tuple of lists (source_id_text, target_id_text) converted
    """
    
    # empty list of converted sentences
    source_text_id = []
    target_text_id = []
    
    # make a list of sentences (extraction)
    source_sentences = source_text.split("\n")
    target_sentences = target_text.split("\n")
    
    # iterating through each sentences (# of sentences in source&target is the same)
    for i in range(len(source_sentences)):
        # extract sentences one by one
        source_sentence = source_sentences[i]
        target_sentence = target_sentences[i]
        
        # make a list of tokens/words (extraction) from the chosen sentence
        source_tokens = source_sentence.split(" ")
        target_tokens = target_sentence.split(" ")
        
        # empty list of converted words to index in the chosen sentence
        source_token_id = []
        target_token_id = []
        
        for token in source_tokens:
            if (token != ""):
                source_token_id.append(source_vocab_to_int[token])
        
        for token in target_tokens:
            if (token != ""):
                target_token_id.append(target_vocab_to_int[token])

        # put <EOS> token at the end of the chosen target sentence
        # this token suggests when to stop creating a sequence
        target_token_id.append(target_vocab_to_int['<EOS>'])
            
        # add each converted sentences in the final list
        source_text_id.append(source_token_id)
        target_text_id.append(target_token_id)
    
    return source_text_id, target_text_id

# %% [markdown]
# ### preprocess and save data

# %%
def preprocess_and_save_data(source_path, target_path, text_to_ids):
    # Preprocess
    source_text = load_data(source_path)
    target_text = load_data(target_path)

    source_text = source_text.lower()
    target_text = target_text.lower()

    source_vocab_to_int, source_int_to_vocab = create_lookup_tables(source_text)
    target_vocab_to_int, target_int_to_vocab = create_lookup_tables(target_text)

    source_text, target_text = text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int)

    # Save Data
    pickle.dump((
        (source_text, target_text),
        (source_vocab_to_int, target_vocab_to_int),
        (source_int_to_vocab, target_int_to_vocab)), open('preprocess.p', 'wb'))

# %% [markdown]
# ### save the pre-processed data

# %%
preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
import numpy as np

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = pickle.load(open('preprocess.p', mode='rb'))

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    input = tf.placeholder(tf.int32, [None, None], name="input")
    targets = tf.placeholder(tf.int32, [None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32)
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    
    return input, targets, learning_rate, keep_prob

tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    go_id = target_vocab_to_int['<GO>']
    after_slice = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    after_concat = tf.concat([tf.fill([batch_size, 1], go_id), after_slice], 1)
    
    return after_concat

tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    enc_cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers)
    enc_cell = tf.contrib.rnn.DropoutWrapper(enc_cell, keep_prob)
    
    _, enc_state = tf.nn.dynamic_rnn(enc_cell, rnn_inputs, dtype=tf.float32)
    return enc_state

tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, 
                                                              train_decoder_fn, 
                                                              dec_embed_input,
                                                              sequence_length,
                                                              scope=decoding_scope)
    logits = output_fn(train_pred)
    return logits

tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, 
                                                                     encoder_state,
                                                                     dec_embeddings,
                                                                     start_of_sequence_id, end_of_sequence_id,
                                                                     maximum_length, vocab_size)
    logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell,
                                                         infer_decoder_fn,
                                                         scope=decoding_scope)
    return logits

tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dec_cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers)    
    
    with tf.variable_scope('decoding') as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, 
                                                                vocab_size, 
                                                                activation_fn=None,
                                                                scope=decoding_scope)
    
    with tf.variable_scope('decoding') as decoding_scope:
        dec_train_logits = decoding_layer_train(encoder_state,
                                                dec_cell,
                                                dec_embed_input, 
                                                sequence_length, 
                                                decoding_scope, 
                                                output_fn, 
                                                keep_prob)

    decoding_scope.reuse_variables() # with tf.variable_scope('decoding', reuse=True) as decoding_scope:
    dec_infer_logits = decoding_layer_infer(encoder_state, 
                                            dec_cell, 
                                            dec_embeddings, 
                                            target_vocab_to_int['<GO>'],
                                            target_vocab_to_int['<EOS>'], 
                                            sequence_length-1, # <EOS> not needed for inference
                                            vocab_size, 
                                            decoding_scope, 
                                            output_fn, 
                                            keep_prob)
    
    return dec_train_logits, dec_infer_logits

tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    enc_state = encoding_layer(enc_embed_input, rnn_size, num_layers, keep_prob)
    
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    train_logits, infer_logits = decoding_layer(dec_embed_input, 
                                                dec_embeddings, 
                                                enc_state,
                                                target_vocab_size, 
                                                sequence_length, 
                                                rnn_size, 
                                                num_layers, 
                                                target_vocab_to_int, 
                                                keep_prob)
    return train_logits, infer_logits

tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
epochs = 3
batch_size = 256
rnn_size = 512
num_layers = 2
encoding_embedding_size = 200 
decoding_embedding_size = 200 
learning_rate = 0.001
keep_probability = 0.5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = pickle.load(open('preprocess.p', mode='rb'))
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
def pad_sentence_batch(sentence_batch):
    """
    Pad sentence with <PAD> id
    """
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [CODES['<PAD>']] * (max_sentence - len(sentence))
            for sentence in sentence_batch]

# %%
def batch_data(source, target, batch_size):
    """
    Batch source and target together
    """
    for batch_i in range(0, len(source)//batch_size):
        start_i = batch_i * batch_size
        source_batch = source[start_i:start_i + batch_size]
        target_batch = target[start_i:start_i + batch_size]
        yield np.array(pad_sentence_batch(source_batch)), np.array(pad_sentence_batch(target_batch))

# %%
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = pad_sentence_batch(source_int_text[:batch_size])
valid_target = pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/538 - Train Accuracy:  0.234, Validation Accuracy:  0.316, Loss:  5.857
# Epoch   0 Batch    1/538 - Train Accuracy:  0.231, Validation Accuracy:  0.316, Loss:  4.938
# Epoch   0 Batch    2/538 - Train Accuracy:  0.264, Validation Accuracy:  0.327, Loss:  5.013
# Epoch   0 Batch    3/538 - Train Accuracy:  0.264, Validation Accuracy:  0.346, Loss:  4.415
# Epoch   0 Batch    4/538 - Train Accuracy:  0.271, Validation Accuracy:  0.344, Loss:  4.191
# Epoch   0 Batch    5/538 - Train Accuracy:  0.298, Validation Accuracy:  0.347, Loss:  4.020
# Epoch   0 Batch    6/538 - Train Accuracy:  0.305, Validation Accuracy:  0.347, Loss:  3.765
# Epoch   0 Batch    7/538 - Train Accuracy:  0.284, Validation Accuracy:  0.350, Loss:  3.646
# Epoch   0 Batch    8/538 - Train Accuracy:  0.297, Validation Accuracy:  0.364, Loss:  3.510
# Epoch   0 Batch    9/538 - Train Accuracy:  0.311, Validation Accuracy:  0.375, Loss:  3.391
# Epoch   0 Batch   10/538 - Train Accuracy:  0.296, Validation Accuracy:  0.374, Loss:  3.412
# Epoch   0 Batch   11/538 - Train Accuracy:  0.305, Validation Accuracy:  0.375, Loss:  3.330
# Epoch   0 Batch   12/538 - Train Accuracy:  0.302, Validation Accuracy:  0.380, Loss:  3.300
# Epoch   0 Batch   13/538 - Train Accuracy:  0.357, Validation Accuracy:  0.386, Loss:  3.050
# Epoch   0 Batch   14/538 - Train Accuracy:  0.315, Validation Accuracy:  0.384, Loss:  3.167
# Epoch   0 Batch   15/538 - Train Accuracy:  0.360, Validation Accuracy:  0.388, Loss:  3.018
# Epoch   0 Batch   16/538 - Train Accuracy:  0.349, Validation Accuracy:  0.389, Loss:  2.957
# Epoch   0 Batch   17/538 - Train Accuracy:  0.338, Validation Accuracy:  0.399, Loss:  3.047
# Epoch   0 Batch   18/538 - Train Accuracy:  0.338, Validation Accuracy:  0.405, Loss:  3.033
# Epoch   0 Batch   19/538 - Train Accuracy:  0.356, Validation Accuracy:  0.425, Loss:  2.988
# Epoch   0 Batch   20/538 - Train Accuracy:  0.384, Validation Accuracy:  0.420, Loss:  2.802
# Epoch   0 Batch   21/538 - Train Accuracy:  0.322, Validation Accuracy:  0.425, Loss:  3.012
# Epoch   0 Batch   22/538 - Train Accuracy:  0.375, Validation Accuracy:  0.434, Loss:  2.847
# Epoch   0 Batch   23/538 - Train Accuracy:  0.384, Validation Accuracy:  0.435, Loss:  2.795
# Epoch   0 Batch   24/538 - Train Accuracy:  0.387, Validation Accuracy:  0.432, Loss:  2.774
# Epoch   0 Batch   25/538 - Train Accuracy:  0.387, Validation Accuracy:  0.441, Loss:  2.757
# Epoch   0 Batch   26/538 - Train Accuracy:  0.373, Validation Accuracy:  0.429, Loss:  2.754
# Epoch   0 Batch   27/538 - Train Accuracy:  0.399, Validation Accuracy:  0.453, Loss:  2.725
# Epoch   0 Batch   28/538 - Train Accuracy:  0.444, Validation Accuracy:  0.446, Loss:  2.441
# Epoch   0 Batch   29/538 - Train Accuracy:  0.429, Validation Accuracy:  0.466, Loss:  2.605
# Epoch   0 Batch   30/538 - Train Accuracy:  0.396, Validation Accuracy:  0.453, Loss:  2.653
# Epoch   0 Batch   31/538 - Train Accuracy:  0.434, Validation Accuracy:  0.468, Loss:  2.547
# Epoch   0 Batch   32/538 - Train Accuracy:  0.417, Validation Accuracy:  0.468, Loss:  2.532
# Epoch   0 Batch   33/538 - Train Accuracy:  0.439, Validation Accuracy:  0.474, Loss:  2.478
# Epoch   0 Batch   34/538 - Train Accuracy:  0.418, Validation Accuracy:  0.470, Loss:  2.543
# Epoch   0 Batch   35/538 - Train Accuracy:  0.411, Validation Accuracy:  0.474, Loss:  2.516
# Epoch   0 Batch   36/538 - Train Accuracy:  0.438, Validation Accuracy:  0.474, Loss:  2.405
# Epoch   0 Batch   37/538 - Train Accuracy:  0.425, Validation Accuracy:  0.479, Loss:  2.443
# Epoch   0 Batch   38/538 - Train Accuracy:  0.411, Validation Accuracy:  0.482, Loss:  2.482
# Epoch   0 Batch   39/538 - Train Accuracy:  0.419, Validation Accuracy:  0.485, Loss:  2.472
# Epoch   0 Batch   40/538 - Train Accuracy:  0.476, Validation Accuracy:  0.476, Loss:  2.238
# Epoch   0 Batch   41/538 - Train Accuracy:  0.438, Validation Accuracy:  0.485, Loss:  2.403
# Epoch   0 Batch   42/538 - Train Accuracy:  0.439, Validation Accuracy:  0.486, Loss:  2.356
# Epoch   0 Batch   43/538 - Train Accuracy:  0.433, Validation Accuracy:  0.480, Loss:  2.386
# Epoch   0 Batch   44/538 - Train Accuracy:  0.419, Validation Accuracy:  0.484, Loss:  2.405
# Epoch   0 Batch   45/538 - Train Accuracy:  0.464, Validation Accuracy:  0.493, Loss:  2.232
# Epoch   0 Batch   46/538 - Train Accuracy:  0.439, Validation Accuracy:  0.492, Loss:  2.326
# Epoch   0 Batch   47/538 - Train Accuracy:  0.459, Validation Accuracy:  0.496, Loss:  2.222
# Epoch   0 Batch   48/538 - Train Accuracy:  0.462, Validation Accuracy:  0.491, Loss:  2.184
# Epoch   0 Batch   49/538 - Train Accuracy:  0.378, Validation Accuracy:  0.445, Loss:  2.372
# Epoch   0 Batch   50/538 - Train Accuracy:  0.380, Validation Accuracy:  0.451, Loss:  2.352
# Epoch   0 Batch   51/538 - Train Accuracy:  0.384, Validation Accuracy:  0.486, Loss:  2.618
# Epoch   0 Batch   52/538 - Train Accuracy:  0.406, Validation Accuracy:  0.459, Loss:  2.244
# Epoch   0 Batch   53/538 - Train Accuracy:  0.487, Validation Accuracy:  0.504, Loss:  2.116
# Epoch   0 Batch   54/538 - Train Accuracy:  0.424, Validation Accuracy:  0.475, Loss:  2.188
# Epoch   0 Batch   55/538 - Train Accuracy:  0.435, Validation Accuracy:  0.499, Loss:  2.333
# Epoch   0 Batch   56/538 - Train Accuracy:  0.431, Validation Accuracy:  0.462, Loss:  2.159
# Epoch   0 Batch   57/538 - Train Accuracy:  0.418, Validation Accuracy:  0.493, Loss:  2.343
# Epoch   0 Batch   58/538 - Train Accuracy:  0.413, Validation Accuracy:  0.500, Loss:  2.263
# Epoch   0 Batch   59/538 - Train Accuracy:  0.432, Validation Accuracy:  0.502, Loss:  2.236
# Epoch   0 Batch   60/538 - Train Accuracy:  0.449, Validation Accuracy:  0.503, Loss:  2.170
# Epoch   0 Batch   61/538 - Train Accuracy:  0.452, Validation Accuracy:  0.509, Loss:  2.148
# Epoch   0 Batch   62/538 - Train Accuracy:  0.469, Validation Accuracy:  0.510, Loss:  2.094
# Epoch   0 Batch   63/538 - Train Accuracy:  0.496, Validation Accuracy:  0.509, Loss:  2.019
# Epoch   0 Batch   64/538 - Train Accuracy:  0.464, Validation Accuracy:  0.496, Loss:  2.041
# Epoch   0 Batch   65/538 - Train Accuracy:  0.437, Validation Accuracy:  0.504, Loss:  2.194
# Epoch   0 Batch   66/538 - Train Accuracy:  0.472, Validation Accuracy:  0.510, Loss:  1.983
# Epoch   0 Batch   67/538 - Train Accuracy:  0.455, Validation Accuracy:  0.507, Loss:  2.059
# Epoch   0 Batch   68/538 - Train Accuracy:  0.480, Validation Accuracy:  0.511, Loss:  1.954
# Epoch   0 Batch   69/538 - Train Accuracy:  0.439, Validation Accuracy:  0.503, Loss:  2.075
# Epoch   0 Batch   70/538 - Train Accuracy:  0.474, Validation Accuracy:  0.506, Loss:  1.970
# Epoch   0 Batch   71/538 - Train Accuracy:  0.454, Validation Accuracy:  0.508, Loss:  2.010
# Epoch   0 Batch   72/538 - Train Accuracy:  0.461, Validation Accuracy:  0.490, Loss:  1.910
# Epoch   0 Batch   73/538 - Train Accuracy:  0.446, Validation Accuracy:  0.507, Loss:  2.023
# Epoch   0 Batch   74/538 - Train Accuracy:  0.457, Validation Accuracy:  0.494, Loss:  1.930
# Epoch   0 Batch   75/538 - Train Accuracy:  0.485, Validation Accuracy:  0.515, Loss:  1.891
# Epoch   0 Batch   76/538 - Train Accuracy:  0.438, Validation Accuracy:  0.507, Loss:  2.011
# Epoch   0 Batch   77/538 - Train Accuracy:  0.441, Validation Accuracy:  0.501, Loss:  1.941
# Epoch   0 Batch   78/538 - Train Accuracy:  0.427, Validation Accuracy:  0.469, Loss:  1.925
# Epoch   0 Batch   79/538 - Train Accuracy:  0.463, Validation Accuracy:  0.498, Loss:  1.906
# Epoch   0 Batch   80/538 - Train Accuracy:  0.417, Validation Accuracy:  0.487, Loss:  1.957
# Epoch   0 Batch   81/538 - Train Accuracy:  0.412, Validation Accuracy:  0.479, Loss:  1.902
# Epoch   0 Batch   82/538 - Train Accuracy:  0.455, Validation Accuracy:  0.501, Loss:  1.846
# Epoch   0 Batch   83/538 - Train Accuracy:  0.410, Validation Accuracy:  0.470, Loss:  1.903
# Epoch   0 Batch   84/538 - Train Accuracy:  0.466, Validation Accuracy:  0.500, Loss:  1.824
# Epoch   0 Batch   85/538 - Train Accuracy:  0.475, Validation Accuracy:  0.492, Loss:  1.719
# Epoch   0 Batch   86/538 - Train Accuracy:  0.391, Validation Accuracy:  0.458, Loss:  1.865
# Epoch   0 Batch   87/538 - Train Accuracy:  0.430, Validation Accuracy:  0.500, Loss:  1.833
# Epoch   0 Batch   88/538 - Train Accuracy:  0.418, Validation Accuracy:  0.472, Loss:  1.866
# Epoch   0 Batch   89/538 - Train Accuracy:  0.446, Validation Accuracy:  0.490, Loss:  1.803
# Epoch   0 Batch   90/538 - Train Accuracy:  0.483, Validation Accuracy:  0.504, Loss:  1.738
# Epoch   0 Batch   91/538 - Train Accuracy:  0.417, Validation Accuracy:  0.479, Loss:  1.851
# Epoch   0 Batch   92/538 - Train Accuracy:  0.445, Validation Accuracy:  0.492, Loss:  1.763
# Epoch   0 Batch   93/538 - Train Accuracy:  0.456, Validation Accuracy:  0.506, Loss:  1.769
# Epoch   0 Batch   94/538 - Train Accuracy:  0.423, Validation Accuracy:  0.488, Loss:  1.812
# Epoch   0 Batch   95/538 - Train Accuracy:  0.474, Validation Accuracy:  0.484, Loss:  1.599
# Epoch   0 Batch   96/538 - Train Accuracy:  0.483, Validation Accuracy:  0.496, Loss:  1.617
# Epoch   0 Batch   97/538 - Train Accuracy:  0.431, Validation Accuracy:  0.491, Loss:  1.726
# Epoch   0 Batch   98/538 - Train Accuracy:  0.441, Validation Accuracy:  0.468, Loss:  1.580
# Epoch   0 Batch   99/538 - Train Accuracy:  0.433, Validation Accuracy:  0.485, Loss:  1.734
# Epoch   0 Batch  100/538 - Train Accuracy:  0.469, Validation Accuracy:  0.504, Loss:  1.642
# Epoch   0 Batch  101/538 - Train Accuracy:  0.433, Validation Accuracy:  0.485, Loss:  1.680
# Epoch   0 Batch  102/538 - Train Accuracy:  0.421, Validation Accuracy:  0.468, Loss:  1.715
# Epoch   0 Batch  103/538 - Train Accuracy:  0.458, Validation Accuracy:  0.500, Loss:  1.650
# Epoch   0 Batch  104/538 - Train Accuracy:  0.449, Validation Accuracy:  0.496, Loss:  1.625
# Epoch   0 Batch  105/538 - Train Accuracy:  0.451, Validation Accuracy:  0.486, Loss:  1.569
# Epoch   0 Batch  106/538 - Train Accuracy:  0.432, Validation Accuracy:  0.493, Loss:  1.615
# Epoch   0 Batch  107/538 - Train Accuracy:  0.415, Validation Accuracy:  0.476, Loss:  1.660
# Epoch   0 Batch  108/538 - Train Accuracy:  0.443, Validation Accuracy:  0.472, Loss:  1.602
# Epoch   0 Batch  109/538 - Train Accuracy:  0.435, Validation Accuracy:  0.487, Loss:  1.586
# Epoch   0 Batch  110/538 - Train Accuracy:  0.431, Validation Accuracy:  0.482, Loss:  1.615
# Epoch   0 Batch  111/538 - Train Accuracy:  0.452, Validation Accuracy:  0.466, Loss:  1.501
# Epoch   0 Batch  112/538 - Train Accuracy:  0.416, Validation Accuracy:  0.471, Loss:  1.577
# Epoch   0 Batch  113/538 - Train Accuracy:  0.424, Validation Accuracy:  0.474, Loss:  1.577
# Epoch   0 Batch  114/538 - Train Accuracy:  0.469, Validation Accuracy:  0.484, Loss:  1.459
# Epoch   0 Batch  115/538 - Train Accuracy:  0.438, Validation Accuracy:  0.485, Loss:  1.505
# Epoch   0 Batch  116/538 - Train Accuracy:  0.438, Validation Accuracy:  0.472, Loss:  1.504
# Epoch   0 Batch  117/538 - Train Accuracy:  0.440, Validation Accuracy:  0.470, Loss:  1.440
# Epoch   0 Batch  118/538 - Train Accuracy:  0.463, Validation Accuracy:  0.493, Loss:  1.443
# Epoch   0 Batch  119/538 - Train Accuracy:  0.471, Validation Accuracy:  0.494, Loss:  1.388
# Epoch   0 Batch  120/538 - Train Accuracy:  0.422, Validation Accuracy:  0.469, Loss:  1.456
# Epoch   0 Batch  121/538 - Train Accuracy:  0.450, Validation Accuracy:  0.461, Loss:  1.390
# Epoch   0 Batch  122/538 - Train Accuracy:  0.444, Validation Accuracy:  0.485, Loss:  1.379
# Epoch   0 Batch  123/538 - Train Accuracy:  0.456, Validation Accuracy:  0.469, Loss:  1.373
# Epoch   0 Batch  124/538 - Train Accuracy:  0.458, Validation Accuracy:  0.472, Loss:  1.312
# Epoch   0 Batch  125/538 - Train Accuracy:  0.457, Validation Accuracy:  0.488, Loss:  1.384
# Epoch   0 Batch  126/538 - Train Accuracy:  0.466, Validation Accuracy:  0.475, Loss:  1.331
# Epoch   0 Batch  127/538 - Train Accuracy:  0.397, Validation Accuracy:  0.462, Loss:  1.425
# Epoch   0 Batch  128/538 - Train Accuracy:  0.449, Validation Accuracy:  0.468, Loss:  1.349
# Epoch   0 Batch  129/538 - Train Accuracy:  0.454, Validation Accuracy:  0.484, Loss:  1.338
# Epoch   0 Batch  130/538 - Train Accuracy:  0.452, Validation Accuracy:  0.481, Loss:  1.327
# Epoch   0 Batch  131/538 - Train Accuracy:  0.409, Validation Accuracy:  0.476, Loss:  1.374
# Epoch   0 Batch  132/538 - Train Accuracy:  0.455, Validation Accuracy:  0.475, Loss:  1.284
# Epoch   0 Batch  133/538 - Train Accuracy:  0.472, Validation Accuracy:  0.480, Loss:  1.240
# Epoch   0 Batch  134/538 - Train Accuracy:  0.406, Validation Accuracy:  0.475, Loss:  1.397
# Epoch   0 Batch  135/538 - Train Accuracy:  0.460, Validation Accuracy:  0.487, Loss:  1.292
# Epoch   0 Batch  136/538 - Train Accuracy:  0.455, Validation Accuracy:  0.497, Loss:  1.295
# Epoch   0 Batch  137/538 - Train Accuracy:  0.464, Validation Accuracy:  0.499, Loss:  1.289
# Epoch   0 Batch  138/538 - Train Accuracy:  0.477, Validation Accuracy:  0.505, Loss:  1.275
# Epoch   0 Batch  139/538 - Train Accuracy:  0.438, Validation Accuracy:  0.488, Loss:  1.365
# Epoch   0 Batch  140/538 - Train Accuracy:  0.439, Validation Accuracy:  0.483, Loss:  1.357
# Epoch   0 Batch  141/538 - Train Accuracy:  0.450, Validation Accuracy:  0.489, Loss:  1.332
# Epoch   0 Batch  142/538 - Train Accuracy:  0.467, Validation Accuracy:  0.465, Loss:  1.211
# Epoch   0 Batch  143/538 - Train Accuracy:  0.411, Validation Accuracy:  0.471, Loss:  1.292
# Epoch   0 Batch  144/538 - Train Accuracy:  0.466, Validation Accuracy:  0.499, Loss:  1.282
# Epoch   0 Batch  145/538 - Train Accuracy:  0.462, Validation Accuracy:  0.495, Loss:  1.243
# Epoch   0 Batch  146/538 - Train Accuracy:  0.483, Validation Accuracy:  0.491, Loss:  1.167
# Epoch   0 Batch  147/538 - Train Accuracy:  0.494, Validation Accuracy:  0.504, Loss:  1.197
# Epoch   0 Batch  148/538 - Train Accuracy:  0.463, Validation Accuracy:  0.512, Loss:  1.291
# Epoch   0 Batch  149/538 - Train Accuracy:  0.446, Validation Accuracy:  0.495, Loss:  1.216
# Epoch   0 Batch  150/538 - Train Accuracy:  0.466, Validation Accuracy:  0.494, Loss:  1.212
# Epoch   0 Batch  151/538 - Train Accuracy:  0.480, Validation Accuracy:  0.506, Loss:  1.171
# Epoch   0 Batch  152/538 - Train Accuracy:  0.479, Validation Accuracy:  0.497, Loss:  1.172
# Epoch   0 Batch  153/538 - Train Accuracy:  0.471, Validation Accuracy:  0.521, Loss:  1.212
# Epoch   0 Batch  154/538 - Train Accuracy:  0.464, Validation Accuracy:  0.502, Loss:  1.146
# Epoch   0 Batch  155/538 - Train Accuracy:  0.502, Validation Accuracy:  0.506, Loss:  1.146
# Epoch   0 Batch  156/538 - Train Accuracy:  0.472, Validation Accuracy:  0.513, Loss:  1.191
# Epoch   0 Batch  157/538 - Train Accuracy:  0.475, Validation Accuracy:  0.513, Loss:  1.136
# Epoch   0 Batch  158/538 - Train Accuracy:  0.470, Validation Accuracy:  0.516, Loss:  1.179
# Epoch   0 Batch  159/538 - Train Accuracy:  0.451, Validation Accuracy:  0.506, Loss:  1.175
# Epoch   0 Batch  160/538 - Train Accuracy:  0.483, Validation Accuracy:  0.507, Loss:  1.107
# Epoch   0 Batch  161/538 - Train Accuracy:  0.496, Validation Accuracy:  0.516, Loss:  1.149
# Epoch   0 Batch  162/538 - Train Accuracy:  0.527, Validation Accuracy:  0.509, Loss:  1.097
# Epoch   0 Batch  163/538 - Train Accuracy:  0.469, Validation Accuracy:  0.498, Loss:  1.129
# Epoch   0 Batch  164/538 - Train Accuracy:  0.504, Validation Accuracy:  0.531, Loss:  1.163
# Epoch   0 Batch  165/538 - Train Accuracy:  0.500, Validation Accuracy:  0.528, Loss:  1.043
# Epoch   0 Batch  166/538 - Train Accuracy:  0.488, Validation Accuracy:  0.527, Loss:  1.109
# Epoch   0 Batch  167/538 - Train Accuracy:  0.529, Validation Accuracy:  0.531, Loss:  1.064
# Epoch   0 Batch  168/538 - Train Accuracy:  0.445, Validation Accuracy:  0.493, Loss:  1.146
# Epoch   0 Batch  169/538 - Train Accuracy:  0.453, Validation Accuracy:  0.497, Loss:  1.086
# Epoch   0 Batch  170/538 - Train Accuracy:  0.514, Validation Accuracy:  0.523, Loss:  1.057
# Epoch   0 Batch  171/538 - Train Accuracy:  0.486, Validation Accuracy:  0.529, Loss:  1.095
# Epoch   0 Batch  172/538 - Train Accuracy:  0.459, Validation Accuracy:  0.495, Loss:  1.050
# Epoch   0 Batch  173/538 - Train Accuracy:  0.488, Validation Accuracy:  0.517, Loss:  1.044
# Epoch   0 Batch  174/538 - Train Accuracy:  0.485, Validation Accuracy:  0.546, Loss:  1.118
# Epoch   0 Batch  175/538 - Train Accuracy:  0.487, Validation Accuracy:  0.544, Loss:  1.089
# Epoch   0 Batch  176/538 - Train Accuracy:  0.505, Validation Accuracy:  0.546, Loss:  1.088
# Epoch   0 Batch  177/538 - Train Accuracy:  0.522, Validation Accuracy:  0.540, Loss:  1.033
# Epoch   0 Batch  178/538 - Train Accuracy:  0.537, Validation Accuracy:  0.536, Loss:  0.988
# Epoch   0 Batch  179/538 - Train Accuracy:  0.504, Validation Accuracy:  0.538, Loss:  1.039
# Epoch   0 Batch  180/538 - Train Accuracy:  0.557, Validation Accuracy:  0.558, Loss:  1.009
# Epoch   0 Batch  181/538 - Train Accuracy:  0.499, Validation Accuracy:  0.561, Loss:  1.075
# Epoch   0 Batch  182/538 - Train Accuracy:  0.502, Validation Accuracy:  0.561, Loss:  1.038
# Epoch   0 Batch  183/538 - Train Accuracy:  0.536, Validation Accuracy:  0.553, Loss:  0.962
# Epoch   0 Batch  184/538 - Train Accuracy:  0.527, Validation Accuracy:  0.544, Loss:  0.965
# Epoch   0 Batch  185/538 - Train Accuracy:  0.516, Validation Accuracy:  0.533, Loss:  1.004
# Epoch   0 Batch  186/538 - Train Accuracy:  0.519, Validation Accuracy:  0.537, Loss:  0.984
# Epoch   0 Batch  187/538 - Train Accuracy:  0.561, Validation Accuracy:  0.555, Loss:  0.944
# Epoch   0 Batch  188/538 - Train Accuracy:  0.500, Validation Accuracy:  0.551, Loss:  0.988
# Epoch   0 Batch  189/538 - Train Accuracy:  0.526, Validation Accuracy:  0.551, Loss:  0.986
# Epoch   0 Batch  190/538 - Train Accuracy:  0.527, Validation Accuracy:  0.557, Loss:  1.001
# Epoch   0 Batch  191/538 - Train Accuracy:  0.543, Validation Accuracy:  0.552, Loss:  0.942
# Epoch   0 Batch  192/538 - Train Accuracy:  0.544, Validation Accuracy:  0.568, Loss:  0.964
# Epoch   0 Batch  193/538 - Train Accuracy:  0.550, Validation Accuracy:  0.566, Loss:  0.924
# Epoch   0 Batch  194/538 - Train Accuracy:  0.522, Validation Accuracy:  0.567, Loss:  0.984
# Epoch   0 Batch  195/538 - Train Accuracy:  0.536, Validation Accuracy:  0.567, Loss:  0.928
# Epoch   0 Batch  196/538 - Train Accuracy:  0.535, Validation Accuracy:  0.561, Loss:  0.932
# Epoch   0 Batch  197/538 - Train Accuracy:  0.538, Validation Accuracy:  0.544, Loss:  0.909
# Epoch   0 Batch  198/538 - Train Accuracy:  0.576, Validation Accuracy:  0.557, Loss:  0.912
# Epoch   0 Batch  199/538 - Train Accuracy:  0.498, Validation Accuracy:  0.556, Loss:  0.973
# Epoch   0 Batch  200/538 - Train Accuracy:  0.533, Validation Accuracy:  0.557, Loss:  0.918
# Epoch   0 Batch  201/538 - Train Accuracy:  0.538, Validation Accuracy:  0.557, Loss:  0.904
# Epoch   0 Batch  202/538 - Train Accuracy:  0.512, Validation Accuracy:  0.558, Loss:  0.958
# Epoch   0 Batch  203/538 - Train Accuracy:  0.522, Validation Accuracy:  0.550, Loss:  0.966
# Epoch   0 Batch  204/538 - Train Accuracy:  0.504, Validation Accuracy:  0.554, Loss:  0.936
# Epoch   0 Batch  205/538 - Train Accuracy:  0.551, Validation Accuracy:  0.554, Loss:  0.876
# Epoch   0 Batch  206/538 - Train Accuracy:  0.507, Validation Accuracy:  0.555, Loss:  0.946
# Epoch   0 Batch  207/538 - Train Accuracy:  0.527, Validation Accuracy:  0.554, Loss:  0.876
# Epoch   0 Batch  208/538 - Train Accuracy:  0.521, Validation Accuracy:  0.556, Loss:  0.927
# Epoch   0 Batch  209/538 - Train Accuracy:  0.513, Validation Accuracy:  0.556, Loss:  0.919
# Epoch   0 Batch  210/538 - Train Accuracy:  0.522, Validation Accuracy:  0.543, Loss:  0.877
# Epoch   0 Batch  211/538 - Train Accuracy:  0.519, Validation Accuracy:  0.547, Loss:  0.936
# Epoch   0 Batch  212/538 - Train Accuracy:  0.538, Validation Accuracy:  0.551, Loss:  0.885
# Epoch   0 Batch  213/538 - Train Accuracy:  0.534, Validation Accuracy:  0.550, Loss:  0.878
# Epoch   0 Batch  214/538 - Train Accuracy:  0.516, Validation Accuracy:  0.545, Loss:  0.885
# Epoch   0 Batch  215/538 - Train Accuracy:  0.515, Validation Accuracy:  0.552, Loss:  0.893
# Epoch   0 Batch  216/538 - Train Accuracy:  0.502, Validation Accuracy:  0.564, Loss:  0.899
# Epoch   0 Batch  217/538 - Train Accuracy:  0.572, Validation Accuracy:  0.566, Loss:  0.838
# Epoch   0 Batch  218/538 - Train Accuracy:  0.511, Validation Accuracy:  0.560, Loss:  0.882
# Epoch   0 Batch  219/538 - Train Accuracy:  0.536, Validation Accuracy:  0.561, Loss:  0.913
# Epoch   0 Batch  220/538 - Train Accuracy:  0.516, Validation Accuracy:  0.562, Loss:  0.846
# Epoch   0 Batch  221/538 - Train Accuracy:  0.544, Validation Accuracy:  0.560, Loss:  0.830
# Epoch   0 Batch  222/538 - Train Accuracy:  0.545, Validation Accuracy:  0.555, Loss:  0.816
# Epoch   0 Batch  223/538 - Train Accuracy:  0.512, Validation Accuracy:  0.537, Loss:  0.886
# Epoch   0 Batch  224/538 - Train Accuracy:  0.487, Validation Accuracy:  0.540, Loss:  0.886
# Epoch   0 Batch  225/538 - Train Accuracy:  0.559, Validation Accuracy:  0.548, Loss:  0.832
# Epoch   0 Batch  226/538 - Train Accuracy:  0.571, Validation Accuracy:  0.563, Loss:  0.827
# Epoch   0 Batch  227/538 - Train Accuracy:  0.568, Validation Accuracy:  0.559, Loss:  0.799
# Epoch   0 Batch  228/538 - Train Accuracy:  0.547, Validation Accuracy:  0.565, Loss:  0.815
# Epoch   0 Batch  229/538 - Train Accuracy:  0.545, Validation Accuracy:  0.573, Loss:  0.830
# Epoch   0 Batch  230/538 - Train Accuracy:  0.527, Validation Accuracy:  0.570, Loss:  0.839
# Epoch   0 Batch  231/538 - Train Accuracy:  0.531, Validation Accuracy:  0.569, Loss:  0.839
# Epoch   0 Batch  232/538 - Train Accuracy:  0.531, Validation Accuracy:  0.557, Loss:  0.829
# Epoch   0 Batch  233/538 - Train Accuracy:  0.574, Validation Accuracy:  0.554, Loss:  0.824
# Epoch   0 Batch  234/538 - Train Accuracy:  0.516, Validation Accuracy:  0.558, Loss:  0.842
# Epoch   0 Batch  235/538 - Train Accuracy:  0.544, Validation Accuracy:  0.562, Loss:  0.793
# Epoch   0 Batch  236/538 - Train Accuracy:  0.535, Validation Accuracy:  0.565, Loss:  0.847
# Epoch   0 Batch  237/538 - Train Accuracy:  0.550, Validation Accuracy:  0.562, Loss:  0.792
# Epoch   0 Batch  238/538 - Train Accuracy:  0.586, Validation Accuracy:  0.561, Loss:  0.788
# Epoch   0 Batch  239/538 - Train Accuracy:  0.543, Validation Accuracy:  0.557, Loss:  0.822
# Epoch   0 Batch  240/538 - Train Accuracy:  0.551, Validation Accuracy:  0.579, Loss:  0.838
# Epoch   0 Batch  241/538 - Train Accuracy:  0.529, Validation Accuracy:  0.575, Loss:  0.819
# Epoch   0 Batch  242/538 - Train Accuracy:  0.573, Validation Accuracy:  0.567, Loss:  0.805
# Epoch   0 Batch  243/538 - Train Accuracy:  0.529, Validation Accuracy:  0.564, Loss:  0.844
# Epoch   0 Batch  244/538 - Train Accuracy:  0.564, Validation Accuracy:  0.561, Loss:  0.780
# Epoch   0 Batch  245/538 - Train Accuracy:  0.550, Validation Accuracy:  0.563, Loss:  0.830
# Epoch   0 Batch  246/538 - Train Accuracy:  0.570, Validation Accuracy:  0.568, Loss:  0.754
# Epoch   0 Batch  247/538 - Train Accuracy:  0.550, Validation Accuracy:  0.569, Loss:  0.811
# Epoch   0 Batch  248/538 - Train Accuracy:  0.550, Validation Accuracy:  0.564, Loss:  0.800
# Epoch   0 Batch  249/538 - Train Accuracy:  0.556, Validation Accuracy:  0.570, Loss:  0.765
# Epoch   0 Batch  250/538 - Train Accuracy:  0.561, Validation Accuracy:  0.577, Loss:  0.775
# Epoch   0 Batch  251/538 - Train Accuracy:  0.554, Validation Accuracy:  0.574, Loss:  0.800
# Epoch   0 Batch  252/538 - Train Accuracy:  0.567, Validation Accuracy:  0.576, Loss:  0.746
# Epoch   0 Batch  253/538 - Train Accuracy:  0.557, Validation Accuracy:  0.574, Loss:  0.745
# Epoch   0 Batch  254/538 - Train Accuracy:  0.554, Validation Accuracy:  0.573, Loss:  0.792
# Epoch   0 Batch  255/538 - Train Accuracy:  0.561, Validation Accuracy:  0.578, Loss:  0.771
# Epoch   0 Batch  256/538 - Train Accuracy:  0.553, Validation Accuracy:  0.577, Loss:  0.796
# Epoch   0 Batch  257/538 - Train Accuracy:  0.586, Validation Accuracy:  0.579, Loss:  0.756
# Epoch   0 Batch  258/538 - Train Accuracy:  0.592, Validation Accuracy:  0.579, Loss:  0.751
# Epoch   0 Batch  259/538 - Train Accuracy:  0.574, Validation Accuracy:  0.578, Loss:  0.745
# Epoch   0 Batch  260/538 - Train Accuracy:  0.561, Validation Accuracy:  0.572, Loss:  0.761
# Epoch   0 Batch  261/538 - Train Accuracy:  0.553, Validation Accuracy:  0.575, Loss:  0.801
# Epoch   0 Batch  262/538 - Train Accuracy:  0.554, Validation Accuracy:  0.586, Loss:  0.760
# Epoch   0 Batch  263/538 - Train Accuracy:  0.569, Validation Accuracy:  0.585, Loss:  0.757
# Epoch   0 Batch  264/538 - Train Accuracy:  0.552, Validation Accuracy:  0.574, Loss:  0.773
# Epoch   0 Batch  265/538 - Train Accuracy:  0.522, Validation Accuracy:  0.571, Loss:  0.794
# Epoch   0 Batch  266/538 - Train Accuracy:  0.584, Validation Accuracy:  0.575, Loss:  0.745
# Epoch   0 Batch  267/538 - Train Accuracy:  0.552, Validation Accuracy:  0.573, Loss:  0.747
# Epoch   0 Batch  268/538 - Train Accuracy:  0.571, Validation Accuracy:  0.567, Loss:  0.712
# Epoch   0 Batch  269/538 - Train Accuracy:  0.548, Validation Accuracy:  0.572, Loss:  0.749
# Epoch   0 Batch  270/538 - Train Accuracy:  0.565, Validation Accuracy:  0.586, Loss:  0.756
# Epoch   0 Batch  271/538 - Train Accuracy:  0.570, Validation Accuracy:  0.595, Loss:  0.761
# Epoch   0 Batch  272/538 - Train Accuracy:  0.545, Validation Accuracy:  0.583, Loss:  0.795
# Epoch   0 Batch  273/538 - Train Accuracy:  0.570, Validation Accuracy:  0.589, Loss:  0.765
# Epoch   0 Batch  274/538 - Train Accuracy:  0.534, Validation Accuracy:  0.584, Loss:  0.792
# Epoch   0 Batch  275/538 - Train Accuracy:  0.551, Validation Accuracy:  0.589, Loss:  0.771
# Epoch   0 Batch  276/538 - Train Accuracy:  0.576, Validation Accuracy:  0.592, Loss:  0.755
# Epoch   0 Batch  277/538 - Train Accuracy:  0.568, Validation Accuracy:  0.583, Loss:  0.742
# Epoch   0 Batch  278/538 - Train Accuracy:  0.569, Validation Accuracy:  0.591, Loss:  0.748
# Epoch   0 Batch  279/538 - Train Accuracy:  0.576, Validation Accuracy:  0.589, Loss:  0.728
# Epoch   0 Batch  280/538 - Train Accuracy:  0.622, Validation Accuracy:  0.593, Loss:  0.703
# Epoch   0 Batch  281/538 - Train Accuracy:  0.583, Validation Accuracy:  0.594, Loss:  0.764
# Epoch   0 Batch  282/538 - Train Accuracy:  0.592, Validation Accuracy:  0.594, Loss:  0.724
# Epoch   0 Batch  283/538 - Train Accuracy:  0.585, Validation Accuracy:  0.590, Loss:  0.726
# Epoch   0 Batch  284/538 - Train Accuracy:  0.593, Validation Accuracy:  0.592, Loss:  0.731
# Epoch   0 Batch  285/538 - Train Accuracy:  0.592, Validation Accuracy:  0.592, Loss:  0.679
# Epoch   0 Batch  286/538 - Train Accuracy:  0.567, Validation Accuracy:  0.584, Loss:  0.728
# Epoch   0 Batch  287/538 - Train Accuracy:  0.603, Validation Accuracy:  0.589, Loss:  0.702
# Epoch   0 Batch  288/538 - Train Accuracy:  0.552, Validation Accuracy:  0.597, Loss:  0.742
# Epoch   0 Batch  289/538 - Train Accuracy:  0.613, Validation Accuracy:  0.596, Loss:  0.661
# Epoch   0 Batch  290/538 - Train Accuracy:  0.560, Validation Accuracy:  0.592, Loss:  0.713
# Epoch   0 Batch  291/538 - Train Accuracy:  0.589, Validation Accuracy:  0.599, Loss:  0.698
# Epoch   0 Batch  292/538 - Train Accuracy:  0.608, Validation Accuracy:  0.605, Loss:  0.683
# Epoch   0 Batch  293/538 - Train Accuracy:  0.589, Validation Accuracy:  0.599, Loss:  0.688
# Epoch   0 Batch  294/538 - Train Accuracy:  0.551, Validation Accuracy:  0.574, Loss:  0.741
# Epoch   0 Batch  295/538 - Train Accuracy:  0.587, Validation Accuracy:  0.568, Loss:  0.668
# Epoch   0 Batch  296/538 - Train Accuracy:  0.565, Validation Accuracy:  0.569, Loss:  0.690
# Epoch   0 Batch  297/538 - Train Accuracy:  0.558, Validation Accuracy:  0.599, Loss:  0.728
# Epoch   0 Batch  298/538 - Train Accuracy:  0.589, Validation Accuracy:  0.595, Loss:  0.688
# Epoch   0 Batch  299/538 - Train Accuracy:  0.584, Validation Accuracy:  0.598, Loss:  0.701
# Epoch   0 Batch  300/538 - Train Accuracy:  0.600, Validation Accuracy:  0.598, Loss:  0.691
# Epoch   0 Batch  301/538 - Train Accuracy:  0.577, Validation Accuracy:  0.603, Loss:  0.710
# Epoch   0 Batch  302/538 - Train Accuracy:  0.611, Validation Accuracy:  0.596, Loss:  0.676
# Epoch   0 Batch  303/538 - Train Accuracy:  0.626, Validation Accuracy:  0.601, Loss:  0.670
# Epoch   0 Batch  304/538 - Train Accuracy:  0.584, Validation Accuracy:  0.600, Loss:  0.702
# Epoch   0 Batch  305/538 - Train Accuracy:  0.589, Validation Accuracy:  0.599, Loss:  0.672
# Epoch   0 Batch  306/538 - Train Accuracy:  0.594, Validation Accuracy:  0.601, Loss:  0.695
# Epoch   0 Batch  307/538 - Train Accuracy:  0.598, Validation Accuracy:  0.605, Loss:  0.701
# Epoch   0 Batch  308/538 - Train Accuracy:  0.611, Validation Accuracy:  0.610, Loss:  0.671
# Epoch   0 Batch  309/538 - Train Accuracy:  0.576, Validation Accuracy:  0.612, Loss:  0.690
# Epoch   0 Batch  310/538 - Train Accuracy:  0.584, Validation Accuracy:  0.594, Loss:  0.681
# Epoch   0 Batch  311/538 - Train Accuracy:  0.588, Validation Accuracy:  0.596, Loss:  0.676
# Epoch   0 Batch  312/538 - Train Accuracy:  0.630, Validation Accuracy:  0.600, Loss:  0.630
# Epoch   0 Batch  313/538 - Train Accuracy:  0.582, Validation Accuracy:  0.602, Loss:  0.726
# Epoch   0 Batch  314/538 - Train Accuracy:  0.593, Validation Accuracy:  0.602, Loss:  0.696
# Epoch   0 Batch  315/538 - Train Accuracy:  0.577, Validation Accuracy:  0.604, Loss:  0.668
# Epoch   0 Batch  316/538 - Train Accuracy:  0.597, Validation Accuracy:  0.602, Loss:  0.668
# Epoch   0 Batch  317/538 - Train Accuracy:  0.604, Validation Accuracy:  0.601, Loss:  0.692
# Epoch   0 Batch  318/538 - Train Accuracy:  0.583, Validation Accuracy:  0.605, Loss:  0.678
# Epoch   0 Batch  319/538 - Train Accuracy:  0.603, Validation Accuracy:  0.614, Loss:  0.668
# Epoch   0 Batch  320/538 - Train Accuracy:  0.603, Validation Accuracy:  0.610, Loss:  0.672
# Epoch   0 Batch  321/538 - Train Accuracy:  0.599, Validation Accuracy:  0.611, Loss:  0.652
# Epoch   0 Batch  322/538 - Train Accuracy:  0.596, Validation Accuracy:  0.607, Loss:  0.659
# Epoch   0 Batch  323/538 - Train Accuracy:  0.595, Validation Accuracy:  0.599, Loss:  0.664
# Epoch   0 Batch  324/538 - Train Accuracy:  0.546, Validation Accuracy:  0.597, Loss:  0.710
# Epoch   0 Batch  325/538 - Train Accuracy:  0.592, Validation Accuracy:  0.595, Loss:  0.665
# Epoch   0 Batch  326/538 - Train Accuracy:  0.576, Validation Accuracy:  0.596, Loss:  0.687
# Epoch   0 Batch  327/538 - Train Accuracy:  0.595, Validation Accuracy:  0.597, Loss:  0.700
# Epoch   0 Batch  328/538 - Train Accuracy:  0.614, Validation Accuracy:  0.606, Loss:  0.645
# Epoch   0 Batch  329/538 - Train Accuracy:  0.610, Validation Accuracy:  0.603, Loss:  0.655
# Epoch   0 Batch  330/538 - Train Accuracy:  0.597, Validation Accuracy:  0.597, Loss:  0.639
# Epoch   0 Batch  331/538 - Train Accuracy:  0.585, Validation Accuracy:  0.605, Loss:  0.659
# Epoch   0 Batch  332/538 - Train Accuracy:  0.586, Validation Accuracy:  0.610, Loss:  0.691
# Epoch   0 Batch  333/538 - Train Accuracy:  0.595, Validation Accuracy:  0.607, Loss:  0.654
# Epoch   0 Batch  334/538 - Train Accuracy:  0.622, Validation Accuracy:  0.611, Loss:  0.622
# Epoch   0 Batch  335/538 - Train Accuracy:  0.599, Validation Accuracy:  0.612, Loss:  0.653
# Epoch   0 Batch  336/538 - Train Accuracy:  0.594, Validation Accuracy:  0.608, Loss:  0.648
# Epoch   0 Batch  337/538 - Train Accuracy:  0.589, Validation Accuracy:  0.611, Loss:  0.647
# Epoch   0 Batch  338/538 - Train Accuracy:  0.589, Validation Accuracy:  0.615, Loss:  0.659
# Epoch   0 Batch  339/538 - Train Accuracy:  0.604, Validation Accuracy:  0.608, Loss:  0.644
# Epoch   0 Batch  340/538 - Train Accuracy:  0.580, Validation Accuracy:  0.608, Loss:  0.693
# Epoch   0 Batch  341/538 - Train Accuracy:  0.587, Validation Accuracy:  0.597, Loss:  0.664
# Epoch   0 Batch  342/538 - Train Accuracy:  0.596, Validation Accuracy:  0.595, Loss:  0.654
# Epoch   0 Batch  343/538 - Train Accuracy:  0.572, Validation Accuracy:  0.597, Loss:  0.686
# Epoch   0 Batch  344/538 - Train Accuracy:  0.567, Validation Accuracy:  0.598, Loss:  0.678
# Epoch   0 Batch  345/538 - Train Accuracy:  0.609, Validation Accuracy:  0.604, Loss:  0.652
# Epoch   0 Batch  346/538 - Train Accuracy:  0.581, Validation Accuracy:  0.603, Loss:  0.666
# Epoch   0 Batch  347/538 - Train Accuracy:  0.582, Validation Accuracy:  0.608, Loss:  0.667
# Epoch   0 Batch  348/538 - Train Accuracy:  0.596, Validation Accuracy:  0.605, Loss:  0.626
# Epoch   0 Batch  349/538 - Train Accuracy:  0.558, Validation Accuracy:  0.604, Loss:  0.656
# Epoch   0 Batch  350/538 - Train Accuracy:  0.601, Validation Accuracy:  0.605, Loss:  0.663
# Epoch   0 Batch  351/538 - Train Accuracy:  0.586, Validation Accuracy:  0.609, Loss:  0.688
# Epoch   0 Batch  352/538 - Train Accuracy:  0.617, Validation Accuracy:  0.603, Loss:  0.660
# Epoch   0 Batch  353/538 - Train Accuracy:  0.589, Validation Accuracy:  0.606, Loss:  0.681
# Epoch   0 Batch  354/538 - Train Accuracy:  0.586, Validation Accuracy:  0.610, Loss:  0.674
# Epoch   0 Batch  355/538 - Train Accuracy:  0.592, Validation Accuracy:  0.615, Loss:  0.666
# Epoch   0 Batch  356/538 - Train Accuracy:  0.597, Validation Accuracy:  0.616, Loss:  0.609
# Epoch   0 Batch  357/538 - Train Accuracy:  0.609, Validation Accuracy:  0.616, Loss:  0.645
# Epoch   0 Batch  358/538 - Train Accuracy:  0.594, Validation Accuracy:  0.617, Loss:  0.663
# Epoch   0 Batch  359/538 - Train Accuracy:  0.609, Validation Accuracy:  0.612, Loss:  0.644
# Epoch   0 Batch  360/538 - Train Accuracy:  0.595, Validation Accuracy:  0.609, Loss:  0.658
# Epoch   0 Batch  361/538 - Train Accuracy:  0.604, Validation Accuracy:  0.617, Loss:  0.639
# Epoch   0 Batch  362/538 - Train Accuracy:  0.602, Validation Accuracy:  0.614, Loss:  0.623
# Epoch   0 Batch  363/538 - Train Accuracy:  0.614, Validation Accuracy:  0.614, Loss:  0.617
# Epoch   0 Batch  364/538 - Train Accuracy:  0.571, Validation Accuracy:  0.616, Loss:  0.683
# Epoch   0 Batch  365/538 - Train Accuracy:  0.619, Validation Accuracy:  0.612, Loss:  0.632
# Epoch   0 Batch  366/538 - Train Accuracy:  0.583, Validation Accuracy:  0.603, Loss:  0.659
# Epoch   0 Batch  367/538 - Train Accuracy:  0.615, Validation Accuracy:  0.608, Loss:  0.632
# Epoch   0 Batch  368/538 - Train Accuracy:  0.651, Validation Accuracy:  0.604, Loss:  0.582
# Epoch   0 Batch  369/538 - Train Accuracy:  0.601, Validation Accuracy:  0.612, Loss:  0.647
# Epoch   0 Batch  370/538 - Train Accuracy:  0.596, Validation Accuracy:  0.609, Loss:  0.662
# Epoch   0 Batch  371/538 - Train Accuracy:  0.610, Validation Accuracy:  0.608, Loss:  0.635
# Epoch   0 Batch  372/538 - Train Accuracy:  0.611, Validation Accuracy:  0.610, Loss:  0.644
# Epoch   0 Batch  373/538 - Train Accuracy:  0.576, Validation Accuracy:  0.615, Loss:  0.630
# Epoch   0 Batch  374/538 - Train Accuracy:  0.588, Validation Accuracy:  0.608, Loss:  0.660
# Epoch   0 Batch  375/538 - Train Accuracy:  0.593, Validation Accuracy:  0.603, Loss:  0.617
# Epoch   0 Batch  376/538 - Train Accuracy:  0.594, Validation Accuracy:  0.616, Loss:  0.650
# Epoch   0 Batch  377/538 - Train Accuracy:  0.613, Validation Accuracy:  0.613, Loss:  0.638
# Epoch   0 Batch  378/538 - Train Accuracy:  0.627, Validation Accuracy:  0.613, Loss:  0.613
# Epoch   0 Batch  379/538 - Train Accuracy:  0.632, Validation Accuracy:  0.610, Loss:  0.600
# Epoch   0 Batch  380/538 - Train Accuracy:  0.601, Validation Accuracy:  0.604, Loss:  0.634
# Epoch   0 Batch  381/538 - Train Accuracy:  0.598, Validation Accuracy:  0.600, Loss:  0.596
# Epoch   0 Batch  382/538 - Train Accuracy:  0.589, Validation Accuracy:  0.617, Loss:  0.646
# Epoch   0 Batch  383/538 - Train Accuracy:  0.602, Validation Accuracy:  0.616, Loss:  0.646
# Epoch   0 Batch  384/538 - Train Accuracy:  0.622, Validation Accuracy:  0.617, Loss:  0.607
# Epoch   0 Batch  385/538 - Train Accuracy:  0.624, Validation Accuracy:  0.615, Loss:  0.611
# Epoch   0 Batch  386/538 - Train Accuracy:  0.601, Validation Accuracy:  0.615, Loss:  0.636
# Epoch   0 Batch  387/538 - Train Accuracy:  0.581, Validation Accuracy:  0.612, Loss:  0.628
# Epoch   0 Batch  388/538 - Train Accuracy:  0.603, Validation Accuracy:  0.610, Loss:  0.616
# Epoch   0 Batch  389/538 - Train Accuracy:  0.599, Validation Accuracy:  0.615, Loss:  0.649
# Epoch   0 Batch  390/538 - Train Accuracy:  0.626, Validation Accuracy:  0.621, Loss:  0.607
# Epoch   0 Batch  391/538 - Train Accuracy:  0.618, Validation Accuracy:  0.632, Loss:  0.603
# Epoch   0 Batch  392/538 - Train Accuracy:  0.608, Validation Accuracy:  0.631, Loss:  0.604
# Epoch   0 Batch  393/538 - Train Accuracy:  0.620, Validation Accuracy:  0.627, Loss:  0.596
# Epoch   0 Batch  394/538 - Train Accuracy:  0.564, Validation Accuracy:  0.625, Loss:  0.643
# Epoch   0 Batch  395/538 - Train Accuracy:  0.597, Validation Accuracy:  0.623, Loss:  0.637
# Epoch   0 Batch  396/538 - Train Accuracy:  0.590, Validation Accuracy:  0.616, Loss:  0.616
# Epoch   0 Batch  397/538 - Train Accuracy:  0.593, Validation Accuracy:  0.607, Loss:  0.633
# Epoch   0 Batch  398/538 - Train Accuracy:  0.597, Validation Accuracy:  0.611, Loss:  0.624
# Epoch   0 Batch  399/538 - Train Accuracy:  0.579, Validation Accuracy:  0.611, Loss:  0.644
# Epoch   0 Batch  400/538 - Train Accuracy:  0.598, Validation Accuracy:  0.618, Loss:  0.604
# Epoch   0 Batch  401/538 - Train Accuracy:  0.611, Validation Accuracy:  0.620, Loss:  0.628
# Epoch   0 Batch  402/538 - Train Accuracy:  0.628, Validation Accuracy:  0.625, Loss:  0.606
# Epoch   0 Batch  403/538 - Train Accuracy:  0.595, Validation Accuracy:  0.627, Loss:  0.625
# Epoch   0 Batch  404/538 - Train Accuracy:  0.621, Validation Accuracy:  0.627, Loss:  0.597
# Epoch   0 Batch  405/538 - Train Accuracy:  0.613, Validation Accuracy:  0.635, Loss:  0.589
# Epoch   0 Batch  406/538 - Train Accuracy:  0.612, Validation Accuracy:  0.627, Loss:  0.588
# Epoch   0 Batch  407/538 - Train Accuracy:  0.616, Validation Accuracy:  0.628, Loss:  0.617
# Epoch   0 Batch  408/538 - Train Accuracy:  0.572, Validation Accuracy:  0.626, Loss:  0.641
# Epoch   0 Batch  409/538 - Train Accuracy:  0.589, Validation Accuracy:  0.623, Loss:  0.635
# Epoch   0 Batch  410/538 - Train Accuracy:  0.615, Validation Accuracy:  0.619, Loss:  0.615
# Epoch   0 Batch  411/538 - Train Accuracy:  0.600, Validation Accuracy:  0.618, Loss:  0.580
# Epoch   0 Batch  412/538 - Train Accuracy:  0.618, Validation Accuracy:  0.620, Loss:  0.580
# Epoch   0 Batch  413/538 - Train Accuracy:  0.618, Validation Accuracy:  0.619, Loss:  0.599
# Epoch   0 Batch  414/538 - Train Accuracy:  0.587, Validation Accuracy:  0.617, Loss:  0.622
# Epoch   0 Batch  415/538 - Train Accuracy:  0.581, Validation Accuracy:  0.620, Loss:  0.628
# Epoch   0 Batch  416/538 - Train Accuracy:  0.640, Validation Accuracy:  0.624, Loss:  0.579
# Epoch   0 Batch  417/538 - Train Accuracy:  0.601, Validation Accuracy:  0.629, Loss:  0.601
# Epoch   0 Batch  418/538 - Train Accuracy:  0.596, Validation Accuracy:  0.630, Loss:  0.625
# Epoch   0 Batch  419/538 - Train Accuracy:  0.635, Validation Accuracy:  0.629, Loss:  0.584
# Epoch   0 Batch  420/538 - Train Accuracy:  0.617, Validation Accuracy:  0.629, Loss:  0.599
# Epoch   0 Batch  421/538 - Train Accuracy:  0.625, Validation Accuracy:  0.625, Loss:  0.571
# Epoch   0 Batch  422/538 - Train Accuracy:  0.616, Validation Accuracy:  0.625, Loss:  0.606
# Epoch   0 Batch  423/538 - Train Accuracy:  0.606, Validation Accuracy:  0.624, Loss:  0.621
# Epoch   0 Batch  424/538 - Train Accuracy:  0.605, Validation Accuracy:  0.634, Loss:  0.594
# Epoch   0 Batch  425/538 - Train Accuracy:  0.619, Validation Accuracy:  0.633, Loss:  0.593
# Epoch   0 Batch  426/538 - Train Accuracy:  0.641, Validation Accuracy:  0.636, Loss:  0.595
# Epoch   0 Batch  427/538 - Train Accuracy:  0.606, Validation Accuracy:  0.636, Loss:  0.612
# Epoch   0 Batch  428/538 - Train Accuracy:  0.641, Validation Accuracy:  0.633, Loss:  0.574
# Epoch   0 Batch  429/538 - Train Accuracy:  0.633, Validation Accuracy:  0.633, Loss:  0.583
# Epoch   0 Batch  430/538 - Train Accuracy:  0.628, Validation Accuracy:  0.629, Loss:  0.597
# Epoch   0 Batch  431/538 - Train Accuracy:  0.629, Validation Accuracy:  0.632, Loss:  0.589
# Epoch   0 Batch  432/538 - Train Accuracy:  0.656, Validation Accuracy:  0.632, Loss:  0.548
# Epoch   0 Batch  433/538 - Train Accuracy:  0.589, Validation Accuracy:  0.623, Loss:  0.628
# Epoch   0 Batch  434/538 - Train Accuracy:  0.597, Validation Accuracy:  0.634, Loss:  0.630
# Epoch   0 Batch  435/538 - Train Accuracy:  0.593, Validation Accuracy:  0.631, Loss:  0.597
# Epoch   0 Batch  436/538 - Train Accuracy:  0.597, Validation Accuracy:  0.636, Loss:  0.632
# Epoch   0 Batch  437/538 - Train Accuracy:  0.589, Validation Accuracy:  0.629, Loss:  0.599
# Epoch   0 Batch  438/538 - Train Accuracy:  0.624, Validation Accuracy:  0.628, Loss:  0.612
# Epoch   0 Batch  439/538 - Train Accuracy:  0.624, Validation Accuracy:  0.634, Loss:  0.600
# Epoch   0 Batch  440/538 - Train Accuracy:  0.599, Validation Accuracy:  0.621, Loss:  0.623
# Epoch   0 Batch  441/538 - Train Accuracy:  0.594, Validation Accuracy:  0.639, Loss:  0.621
# Epoch   0 Batch  442/538 - Train Accuracy:  0.644, Validation Accuracy:  0.631, Loss:  0.542
# Epoch   0 Batch  443/538 - Train Accuracy:  0.643, Validation Accuracy:  0.634, Loss:  0.584
# Epoch   0 Batch  444/538 - Train Accuracy:  0.677, Validation Accuracy:  0.640, Loss:  0.558
# Epoch   0 Batch  445/538 - Train Accuracy:  0.642, Validation Accuracy:  0.634, Loss:  0.580
# Epoch   0 Batch  446/538 - Train Accuracy:  0.635, Validation Accuracy:  0.629, Loss:  0.559
# Epoch   0 Batch  447/538 - Train Accuracy:  0.594, Validation Accuracy:  0.632, Loss:  0.602
# Epoch   0 Batch  448/538 - Train Accuracy:  0.627, Validation Accuracy:  0.630, Loss:  0.555
# Epoch   0 Batch  449/538 - Train Accuracy:  0.612, Validation Accuracy:  0.635, Loss:  0.606
# Epoch   0 Batch  450/538 - Train Accuracy:  0.639, Validation Accuracy:  0.640, Loss:  0.591
# Epoch   0 Batch  451/538 - Train Accuracy:  0.624, Validation Accuracy:  0.640, Loss:  0.591
# Epoch   0 Batch  452/538 - Train Accuracy:  0.619, Validation Accuracy:  0.638, Loss:  0.570
# Epoch   0 Batch  453/538 - Train Accuracy:  0.615, Validation Accuracy:  0.635, Loss:  0.586
# Epoch   0 Batch  454/538 - Train Accuracy:  0.631, Validation Accuracy:  0.637, Loss:  0.560
# Epoch   0 Batch  455/538 - Train Accuracy:  0.643, Validation Accuracy:  0.634, Loss:  0.523
# Epoch   0 Batch  456/538 - Train Accuracy:  0.691, Validation Accuracy:  0.636, Loss:  0.514
# Epoch   0 Batch  457/538 - Train Accuracy:  0.619, Validation Accuracy:  0.637, Loss:  0.599
# Epoch   0 Batch  458/538 - Train Accuracy:  0.628, Validation Accuracy:  0.637, Loss:  0.549
# Epoch   0 Batch  459/538 - Train Accuracy:  0.640, Validation Accuracy:  0.638, Loss:  0.574
# Epoch   0 Batch  460/538 - Train Accuracy:  0.605, Validation Accuracy:  0.638, Loss:  0.552
# Epoch   0 Batch  461/538 - Train Accuracy:  0.594, Validation Accuracy:  0.642, Loss:  0.613
# Epoch   0 Batch  462/538 - Train Accuracy:  0.618, Validation Accuracy:  0.643, Loss:  0.564
# Epoch   0 Batch  463/538 - Train Accuracy:  0.609, Validation Accuracy:  0.638, Loss:  0.578
# Epoch   0 Batch  464/538 - Train Accuracy:  0.611, Validation Accuracy:  0.643, Loss:  0.580
# Epoch   0 Batch  465/538 - Train Accuracy:  0.594, Validation Accuracy:  0.637, Loss:  0.587
# Epoch   0 Batch  466/538 - Train Accuracy:  0.625, Validation Accuracy:  0.638, Loss:  0.578
# Epoch   0 Batch  467/538 - Train Accuracy:  0.620, Validation Accuracy:  0.640, Loss:  0.560
# Epoch   0 Batch  468/538 - Train Accuracy:  0.653, Validation Accuracy:  0.638, Loss:  0.576
# Epoch   0 Batch  469/538 - Train Accuracy:  0.624, Validation Accuracy:  0.642, Loss:  0.573
# Epoch   0 Batch  470/538 - Train Accuracy:  0.643, Validation Accuracy:  0.642, Loss:  0.553
# Epoch   0 Batch  471/538 - Train Accuracy:  0.639, Validation Accuracy:  0.646, Loss:  0.560
# Epoch   0 Batch  472/538 - Train Accuracy:  0.650, Validation Accuracy:  0.641, Loss:  0.537
# Epoch   0 Batch  473/538 - Train Accuracy:  0.588, Validation Accuracy:  0.647, Loss:  0.576
# Epoch   0 Batch  474/538 - Train Accuracy:  0.643, Validation Accuracy:  0.646, Loss:  0.529
# Epoch   0 Batch  475/538 - Train Accuracy:  0.630, Validation Accuracy:  0.648, Loss:  0.556
# Epoch   0 Batch  476/538 - Train Accuracy:  0.605, Validation Accuracy:  0.640, Loss:  0.567
# Epoch   0 Batch  477/538 - Train Accuracy:  0.634, Validation Accuracy:  0.635, Loss:  0.559
# Epoch   0 Batch  478/538 - Train Accuracy:  0.647, Validation Accuracy:  0.638, Loss:  0.533
# Epoch   0 Batch  479/538 - Train Accuracy:  0.646, Validation Accuracy:  0.629, Loss:  0.529
# Epoch   0 Batch  480/538 - Train Accuracy:  0.633, Validation Accuracy:  0.630, Loss:  0.551
# Epoch   0 Batch  481/538 - Train Accuracy:  0.646, Validation Accuracy:  0.632, Loss:  0.528
# Epoch   0 Batch  482/538 - Train Accuracy:  0.657, Validation Accuracy:  0.642, Loss:  0.496
# Epoch   0 Batch  483/538 - Train Accuracy:  0.603, Validation Accuracy:  0.641, Loss:  0.564
# Epoch   0 Batch  484/538 - Train Accuracy:  0.644, Validation Accuracy:  0.636, Loss:  0.553
# Epoch   0 Batch  485/538 - Train Accuracy:  0.623, Validation Accuracy:  0.634, Loss:  0.539
# Epoch   0 Batch  486/538 - Train Accuracy:  0.635, Validation Accuracy:  0.637, Loss:  0.538
# Epoch   0 Batch  487/538 - Train Accuracy:  0.644, Validation Accuracy:  0.648, Loss:  0.517
# Epoch   0 Batch  488/538 - Train Accuracy:  0.652, Validation Accuracy:  0.648, Loss:  0.549
# Epoch   0 Batch  489/538 - Train Accuracy:  0.617, Validation Accuracy:  0.647, Loss:  0.566
# Epoch   0 Batch  490/538 - Train Accuracy:  0.632, Validation Accuracy:  0.649, Loss:  0.546
# Epoch   0 Batch  491/538 - Train Accuracy:  0.614, Validation Accuracy:  0.654, Loss:  0.575
# Epoch   0 Batch  492/538 - Train Accuracy:  0.641, Validation Accuracy:  0.651, Loss:  0.554
# Epoch   0 Batch  493/538 - Train Accuracy:  0.612, Validation Accuracy:  0.653, Loss:  0.537
# Epoch   0 Batch  494/538 - Train Accuracy:  0.625, Validation Accuracy:  0.651, Loss:  0.560
# Epoch   0 Batch  495/538 - Train Accuracy:  0.647, Validation Accuracy:  0.656, Loss:  0.561
# Epoch   0 Batch  496/538 - Train Accuracy:  0.642, Validation Accuracy:  0.648, Loss:  0.542
# Epoch   0 Batch  497/538 - Train Accuracy:  0.649, Validation Accuracy:  0.648, Loss:  0.523
# Epoch   0 Batch  498/538 - Train Accuracy:  0.609, Validation Accuracy:  0.650, Loss:  0.546
# Epoch   0 Batch  499/538 - Train Accuracy:  0.660, Validation Accuracy:  0.654, Loss:  0.524
# Epoch   0 Batch  500/538 - Train Accuracy:  0.658, Validation Accuracy:  0.651, Loss:  0.494
# Epoch   0 Batch  501/538 - Train Accuracy:  0.653, Validation Accuracy:  0.649, Loss:  0.526
# Epoch   0 Batch  502/538 - Train Accuracy:  0.612, Validation Accuracy:  0.651, Loss:  0.536
# Epoch   0 Batch  503/538 - Train Accuracy:  0.669, Validation Accuracy:  0.650, Loss:  0.523
# Epoch   0 Batch  504/538 - Train Accuracy:  0.646, Validation Accuracy:  0.650, Loss:  0.531
# Epoch   0 Batch  505/538 - Train Accuracy:  0.643, Validation Accuracy:  0.656, Loss:  0.528
# Epoch   0 Batch  506/538 - Train Accuracy:  0.652, Validation Accuracy:  0.655, Loss:  0.528
# Epoch   0 Batch  507/538 - Train Accuracy:  0.626, Validation Accuracy:  0.651, Loss:  0.550
# Epoch   0 Batch  508/538 - Train Accuracy:  0.652, Validation Accuracy:  0.653, Loss:  0.509
# Epoch   0 Batch  509/538 - Train Accuracy:  0.639, Validation Accuracy:  0.660, Loss:  0.540
# Epoch   0 Batch  510/538 - Train Accuracy:  0.644, Validation Accuracy:  0.655, Loss:  0.524
# Epoch   0 Batch  511/538 - Train Accuracy:  0.659, Validation Accuracy:  0.649, Loss:  0.511
# Epoch   0 Batch  512/538 - Train Accuracy:  0.664, Validation Accuracy:  0.646, Loss:  0.512
# Epoch   0 Batch  513/538 - Train Accuracy:  0.615, Validation Accuracy:  0.649, Loss:  0.540
# Epoch   0 Batch  514/538 - Train Accuracy:  0.621, Validation Accuracy:  0.659, Loss:  0.537
# Epoch   0 Batch  515/538 - Train Accuracy:  0.634, Validation Accuracy:  0.656, Loss:  0.527
# ...
# Epoch   2 Batch  366/538 - Train Accuracy:  0.925, Validation Accuracy:  0.911, Loss:  0.067
# Epoch   2 Batch  367/538 - Train Accuracy:  0.919, Validation Accuracy:  0.914, Loss:  0.055
# Epoch   2 Batch  368/538 - Train Accuracy:  0.924, Validation Accuracy:  0.917, Loss:  0.056
# Epoch   2 Batch  369/538 - Train Accuracy:  0.925, Validation Accuracy:  0.910, Loss:  0.056
# Epoch   2 Batch  370/538 - Train Accuracy:  0.922, Validation Accuracy:  0.914, Loss:  0.063
# Epoch   2 Batch  371/538 - Train Accuracy:  0.931, Validation Accuracy:  0.914, Loss:  0.064
# Epoch   2 Batch  372/538 - Train Accuracy:  0.946, Validation Accuracy:  0.910, Loss:  0.058
# Epoch   2 Batch  373/538 - Train Accuracy:  0.920, Validation Accuracy:  0.908, Loss:  0.053
# Epoch   2 Batch  374/538 - Train Accuracy:  0.935, Validation Accuracy:  0.906, Loss:  0.057
# Epoch   2 Batch  375/538 - Train Accuracy:  0.931, Validation Accuracy:  0.900, Loss:  0.057
# Epoch   2 Batch  376/538 - Train Accuracy:  0.907, Validation Accuracy:  0.903, Loss:  0.063
# Epoch   2 Batch  377/538 - Train Accuracy:  0.918, Validation Accuracy:  0.898, Loss:  0.061
# Epoch   2 Batch  378/538 - Train Accuracy:  0.925, Validation Accuracy:  0.900, Loss:  0.055
# Epoch   2 Batch  379/538 - Train Accuracy:  0.924, Validation Accuracy:  0.913, Loss:  0.056
# Epoch   2 Batch  380/538 - Train Accuracy:  0.911, Validation Accuracy:  0.912, Loss:  0.060
# Epoch   2 Batch  381/538 - Train Accuracy:  0.932, Validation Accuracy:  0.913, Loss:  0.054
# Epoch   2 Batch  382/538 - Train Accuracy:  0.903, Validation Accuracy:  0.919, Loss:  0.056
# Epoch   2 Batch  383/538 - Train Accuracy:  0.928, Validation Accuracy:  0.924, Loss:  0.060
# Epoch   2 Batch  384/538 - Train Accuracy:  0.915, Validation Accuracy:  0.923, Loss:  0.059
# Epoch   2 Batch  385/538 - Train Accuracy:  0.927, Validation Accuracy:  0.921, Loss:  0.058
# Epoch   2 Batch  386/538 - Train Accuracy:  0.924, Validation Accuracy:  0.923, Loss:  0.065
# Epoch   2 Batch  387/538 - Train Accuracy:  0.919, Validation Accuracy:  0.928, Loss:  0.063
# Epoch   2 Batch  388/538 - Train Accuracy:  0.931, Validation Accuracy:  0.926, Loss:  0.061
# Epoch   2 Batch  389/538 - Train Accuracy:  0.901, Validation Accuracy:  0.922, Loss:  0.072
# Epoch   2 Batch  390/538 - Train Accuracy:  0.935, Validation Accuracy:  0.913, Loss:  0.052
# Epoch   2 Batch  391/538 - Train Accuracy:  0.928, Validation Accuracy:  0.916, Loss:  0.055
# Epoch   2 Batch  392/538 - Train Accuracy:  0.916, Validation Accuracy:  0.920, Loss:  0.058
# Epoch   2 Batch  393/538 - Train Accuracy:  0.922, Validation Accuracy:  0.911, Loss:  0.058
# Epoch   2 Batch  394/538 - Train Accuracy:  0.900, Validation Accuracy:  0.916, Loss:  0.064
# Epoch   2 Batch  395/538 - Train Accuracy:  0.916, Validation Accuracy:  0.915, Loss:  0.069
# Epoch   2 Batch  396/538 - Train Accuracy:  0.922, Validation Accuracy:  0.916, Loss:  0.054
# Epoch   2 Batch  397/538 - Train Accuracy:  0.925, Validation Accuracy:  0.916, Loss:  0.064
# Epoch   2 Batch  398/538 - Train Accuracy:  0.926, Validation Accuracy:  0.919, Loss:  0.056
# Epoch   2 Batch  399/538 - Train Accuracy:  0.917, Validation Accuracy:  0.910, Loss:  0.063
# Epoch   2 Batch  400/538 - Train Accuracy:  0.926, Validation Accuracy:  0.906, Loss:  0.058
# Epoch   2 Batch  401/538 - Train Accuracy:  0.937, Validation Accuracy:  0.911, Loss:  0.056
# Epoch   2 Batch  402/538 - Train Accuracy:  0.920, Validation Accuracy:  0.906, Loss:  0.055
# Epoch   2 Batch  403/538 - Train Accuracy:  0.917, Validation Accuracy:  0.906, Loss:  0.064
# Epoch   2 Batch  404/538 - Train Accuracy:  0.911, Validation Accuracy:  0.904, Loss:  0.059
# Epoch   2 Batch  405/538 - Train Accuracy:  0.921, Validation Accuracy:  0.904, Loss:  0.055
# Epoch   2 Batch  406/538 - Train Accuracy:  0.913, Validation Accuracy:  0.901, Loss:  0.061
# Epoch   2 Batch  407/538 - Train Accuracy:  0.932, Validation Accuracy:  0.909, Loss:  0.062
# Epoch   2 Batch  408/538 - Train Accuracy:  0.907, Validation Accuracy:  0.917, Loss:  0.062
# Epoch   2 Batch  409/538 - Train Accuracy:  0.907, Validation Accuracy:  0.925, Loss:  0.061
# Epoch   2 Batch  410/538 - Train Accuracy:  0.928, Validation Accuracy:  0.928, Loss:  0.058
# Epoch   2 Batch  411/538 - Train Accuracy:  0.939, Validation Accuracy:  0.919, Loss:  0.061
# Epoch   2 Batch  412/538 - Train Accuracy:  0.921, Validation Accuracy:  0.921, Loss:  0.051
# Epoch   2 Batch  413/538 - Train Accuracy:  0.917, Validation Accuracy:  0.914, Loss:  0.058
# Epoch   2 Batch  414/538 - Train Accuracy:  0.874, Validation Accuracy:  0.918, Loss:  0.073
# Epoch   2 Batch  415/538 - Train Accuracy:  0.894, Validation Accuracy:  0.911, Loss:  0.060
# Epoch   2 Batch  416/538 - Train Accuracy:  0.923, Validation Accuracy:  0.905, Loss:  0.059
# Epoch   2 Batch  417/538 - Train Accuracy:  0.927, Validation Accuracy:  0.912, Loss:  0.059
# Epoch   2 Batch  418/538 - Train Accuracy:  0.920, Validation Accuracy:  0.917, Loss:  0.061
# Epoch   2 Batch  419/538 - Train Accuracy:  0.917, Validation Accuracy:  0.927, Loss:  0.051
# Epoch   2 Batch  420/538 - Train Accuracy:  0.925, Validation Accuracy:  0.932, Loss:  0.056
# Epoch   2 Batch  421/538 - Train Accuracy:  0.917, Validation Accuracy:  0.932, Loss:  0.054
# Epoch   2 Batch  422/538 - Train Accuracy:  0.926, Validation Accuracy:  0.925, Loss:  0.058
# Epoch   2 Batch  423/538 - Train Accuracy:  0.920, Validation Accuracy:  0.922, Loss:  0.060
# Epoch   2 Batch  424/538 - Train Accuracy:  0.906, Validation Accuracy:  0.921, Loss:  0.063
# Epoch   2 Batch  425/538 - Train Accuracy:  0.920, Validation Accuracy:  0.920, Loss:  0.071
# Epoch   2 Batch  426/538 - Train Accuracy:  0.928, Validation Accuracy:  0.917, Loss:  0.059
# Epoch   2 Batch  427/538 - Train Accuracy:  0.912, Validation Accuracy:  0.919, Loss:  0.060
# Epoch   2 Batch  428/538 - Train Accuracy:  0.932, Validation Accuracy:  0.907, Loss:  0.050
# Epoch   2 Batch  429/538 - Train Accuracy:  0.943, Validation Accuracy:  0.912, Loss:  0.056
# Epoch   2 Batch  430/538 - Train Accuracy:  0.918, Validation Accuracy:  0.910, Loss:  0.054
# Epoch   2 Batch  431/538 - Train Accuracy:  0.930, Validation Accuracy:  0.913, Loss:  0.054
# Epoch   2 Batch  432/538 - Train Accuracy:  0.919, Validation Accuracy:  0.906, Loss:  0.057
# Epoch   2 Batch  433/538 - Train Accuracy:  0.889, Validation Accuracy:  0.908, Loss:  0.083
# Epoch   2 Batch  434/538 - Train Accuracy:  0.907, Validation Accuracy:  0.914, Loss:  0.060
# Epoch   2 Batch  435/538 - Train Accuracy:  0.914, Validation Accuracy:  0.912, Loss:  0.053
# Epoch   2 Batch  436/538 - Train Accuracy:  0.893, Validation Accuracy:  0.909, Loss:  0.067
# Epoch   2 Batch  437/538 - Train Accuracy:  0.924, Validation Accuracy:  0.915, Loss:  0.057
# Epoch   2 Batch  438/538 - Train Accuracy:  0.911, Validation Accuracy:  0.918, Loss:  0.054
# Epoch   2 Batch  439/538 - Train Accuracy:  0.929, Validation Accuracy:  0.926, Loss:  0.060
# Epoch   2 Batch  440/538 - Train Accuracy:  0.916, Validation Accuracy:  0.923, Loss:  0.059
# Epoch   2 Batch  441/538 - Train Accuracy:  0.902, Validation Accuracy:  0.926, Loss:  0.070
# Epoch   2 Batch  442/538 - Train Accuracy:  0.923, Validation Accuracy:  0.918, Loss:  0.046
# Epoch   2 Batch  443/538 - Train Accuracy:  0.927, Validation Accuracy:  0.918, Loss:  0.055
# Epoch   2 Batch  444/538 - Train Accuracy:  0.922, Validation Accuracy:  0.911, Loss:  0.052
# Epoch   2 Batch  445/538 - Train Accuracy:  0.935, Validation Accuracy:  0.911, Loss:  0.048
# Epoch   2 Batch  446/538 - Train Accuracy:  0.931, Validation Accuracy:  0.914, Loss:  0.056
# Epoch   2 Batch  447/538 - Train Accuracy:  0.911, Validation Accuracy:  0.914, Loss:  0.056
# Epoch   2 Batch  448/538 - Train Accuracy:  0.927, Validation Accuracy:  0.911, Loss:  0.047
# Epoch   2 Batch  449/538 - Train Accuracy:  0.923, Validation Accuracy:  0.920, Loss:  0.065
# Epoch   2 Batch  450/538 - Train Accuracy:  0.903, Validation Accuracy:  0.925, Loss:  0.067
# Epoch   2 Batch  451/538 - Train Accuracy:  0.891, Validation Accuracy:  0.925, Loss:  0.059
# Epoch   2 Batch  452/538 - Train Accuracy:  0.920, Validation Accuracy:  0.928, Loss:  0.052
# Epoch   2 Batch  453/538 - Train Accuracy:  0.927, Validation Accuracy:  0.923, Loss:  0.060
# Epoch   2 Batch  454/538 - Train Accuracy:  0.901, Validation Accuracy:  0.922, Loss:  0.063
# Epoch   2 Batch  455/538 - Train Accuracy:  0.936, Validation Accuracy:  0.911, Loss:  0.054
# Epoch   2 Batch  456/538 - Train Accuracy:  0.920, Validation Accuracy:  0.914, Loss:  0.066
# Epoch   2 Batch  457/538 - Train Accuracy:  0.912, Validation Accuracy:  0.912, Loss:  0.052
# Epoch   2 Batch  458/538 - Train Accuracy:  0.920, Validation Accuracy:  0.912, Loss:  0.055
# Epoch   2 Batch  459/538 - Train Accuracy:  0.927, Validation Accuracy:  0.910, Loss:  0.049
# Epoch   2 Batch  460/538 - Train Accuracy:  0.905, Validation Accuracy:  0.915, Loss:  0.057
# Epoch   2 Batch  461/538 - Train Accuracy:  0.935, Validation Accuracy:  0.915, Loss:  0.058
# Epoch   2 Batch  462/538 - Train Accuracy:  0.914, Validation Accuracy:  0.911, Loss:  0.053
# Epoch   2 Batch  463/538 - Train Accuracy:  0.896, Validation Accuracy:  0.910, Loss:  0.060
# Epoch   2 Batch  464/538 - Train Accuracy:  0.916, Validation Accuracy:  0.914, Loss:  0.052
# Epoch   2 Batch  465/538 - Train Accuracy:  0.922, Validation Accuracy:  0.913, Loss:  0.053
# Epoch   2 Batch  466/538 - Train Accuracy:  0.922, Validation Accuracy:  0.915, Loss:  0.051
# Epoch   2 Batch  467/538 - Train Accuracy:  0.936, Validation Accuracy:  0.916, Loss:  0.055
# Epoch   2 Batch  468/538 - Train Accuracy:  0.939, Validation Accuracy:  0.911, Loss:  0.060
# Epoch   2 Batch  469/538 - Train Accuracy:  0.932, Validation Accuracy:  0.901, Loss:  0.052
# Epoch   2 Batch  470/538 - Train Accuracy:  0.916, Validation Accuracy:  0.900, Loss:  0.053
# Epoch   2 Batch  471/538 - Train Accuracy:  0.921, Validation Accuracy:  0.904, Loss:  0.046
# Epoch   2 Batch  472/538 - Train Accuracy:  0.956, Validation Accuracy:  0.911, Loss:  0.044
# Epoch   2 Batch  473/538 - Train Accuracy:  0.912, Validation Accuracy:  0.922, Loss:  0.058
# Epoch   2 Batch  474/538 - Train Accuracy:  0.939, Validation Accuracy:  0.928, Loss:  0.044
# Epoch   2 Batch  475/538 - Train Accuracy:  0.928, Validation Accuracy:  0.928, Loss:  0.052
# Epoch   2 Batch  476/538 - Train Accuracy:  0.927, Validation Accuracy:  0.922, Loss:  0.050
# Epoch   2 Batch  477/538 - Train Accuracy:  0.907, Validation Accuracy:  0.914, Loss:  0.061
# Epoch   2 Batch  478/538 - Train Accuracy:  0.944, Validation Accuracy:  0.913, Loss:  0.045
# Epoch   2 Batch  479/538 - Train Accuracy:  0.917, Validation Accuracy:  0.912, Loss:  0.049
# Epoch   2 Batch  480/538 - Train Accuracy:  0.932, Validation Accuracy:  0.907, Loss:  0.048
# Epoch   2 Batch  481/538 - Train Accuracy:  0.939, Validation Accuracy:  0.900, Loss:  0.051
# Epoch   2 Batch  482/538 - Train Accuracy:  0.931, Validation Accuracy:  0.914, Loss:  0.047
# Epoch   2 Batch  483/538 - Train Accuracy:  0.896, Validation Accuracy:  0.917, Loss:  0.062
# Epoch   2 Batch  484/538 - Train Accuracy:  0.930, Validation Accuracy:  0.924, Loss:  0.057
# Epoch   2 Batch  485/538 - Train Accuracy:  0.929, Validation Accuracy:  0.915, Loss:  0.056
# Epoch   2 Batch  486/538 - Train Accuracy:  0.944, Validation Accuracy:  0.919, Loss:  0.040
# Epoch   2 Batch  487/538 - Train Accuracy:  0.918, Validation Accuracy:  0.922, Loss:  0.048
# Epoch   2 Batch  488/538 - Train Accuracy:  0.940, Validation Accuracy:  0.925, Loss:  0.042
# Epoch   2 Batch  489/538 - Train Accuracy:  0.903, Validation Accuracy:  0.922, Loss:  0.055
# Epoch   2 Batch  490/538 - Train Accuracy:  0.922, Validation Accuracy:  0.934, Loss:  0.048
# Epoch   2 Batch  491/538 - Train Accuracy:  0.885, Validation Accuracy:  0.930, Loss:  0.060
# Epoch   2 Batch  492/538 - Train Accuracy:  0.939, Validation Accuracy:  0.925, Loss:  0.047
# Epoch   2 Batch  493/538 - Train Accuracy:  0.920, Validation Accuracy:  0.920, Loss:  0.046
# Epoch   2 Batch  494/538 - Train Accuracy:  0.915, Validation Accuracy:  0.911, Loss:  0.057
# Epoch   2 Batch  495/538 - Train Accuracy:  0.930, Validation Accuracy:  0.919, Loss:  0.053
# Epoch   2 Batch  496/538 - Train Accuracy:  0.944, Validation Accuracy:  0.926, Loss:  0.042
# Epoch   2 Batch  497/538 - Train Accuracy:  0.941, Validation Accuracy:  0.926, Loss:  0.048
# Epoch   2 Batch  498/538 - Train Accuracy:  0.919, Validation Accuracy:  0.928, Loss:  0.049
# Epoch   2 Batch  499/538 - Train Accuracy:  0.929, Validation Accuracy:  0.924, Loss:  0.052
# Epoch   2 Batch  500/538 - Train Accuracy:  0.942, Validation Accuracy:  0.928, Loss:  0.037
# Epoch   2 Batch  501/538 - Train Accuracy:  0.935, Validation Accuracy:  0.926, Loss:  0.053
# Epoch   2 Batch  502/538 - Train Accuracy:  0.919, Validation Accuracy:  0.924, Loss:  0.043
# Epoch   2 Batch  503/538 - Train Accuracy:  0.942, Validation Accuracy:  0.925, Loss:  0.053
# Epoch   2 Batch  504/538 - Train Accuracy:  0.942, Validation Accuracy:  0.925, Loss:  0.040
# Epoch   2 Batch  505/538 - Train Accuracy:  0.947, Validation Accuracy:  0.924, Loss:  0.039
# Epoch   2 Batch  506/538 - Train Accuracy:  0.934, Validation Accuracy:  0.920, Loss:  0.041
# Epoch   2 Batch  507/538 - Train Accuracy:  0.903, Validation Accuracy:  0.929, Loss:  0.054
# Epoch   2 Batch  508/538 - Train Accuracy:  0.920, Validation Accuracy:  0.924, Loss:  0.047
# Epoch   2 Batch  509/538 - Train Accuracy:  0.927, Validation Accuracy:  0.933, Loss:  0.052
# Epoch   2 Batch  510/538 - Train Accuracy:  0.928, Validation Accuracy:  0.930, Loss:  0.049
# Epoch   2 Batch  511/538 - Train Accuracy:  0.913, Validation Accuracy:  0.927, Loss:  0.051
# Epoch   2 Batch  512/538 - Train Accuracy:  0.944, Validation Accuracy:  0.928, Loss:  0.052
# Epoch   2 Batch  513/538 - Train Accuracy:  0.902, Validation Accuracy:  0.928, Loss:  0.045
# Epoch   2 Batch  514/538 - Train Accuracy:  0.923, Validation Accuracy:  0.931, Loss:  0.047
# Epoch   2 Batch  515/538 - Train Accuracy:  0.929, Validation Accuracy:  0.923, Loss:  0.054
# Epoch   2 Batch  516/538 - Train Accuracy:  0.915, Validation Accuracy:  0.928, Loss:  0.053
# Epoch   2 Batch  517/538 - Train Accuracy:  0.934, Validation Accuracy:  0.919, Loss:  0.044
# Epoch   2 Batch  518/538 - Train Accuracy:  0.909, Validation Accuracy:  0.916, Loss:  0.055
# Epoch   2 Batch  519/538 - Train Accuracy:  0.927, Validation Accuracy:  0.922, Loss:  0.053
# Epoch   2 Batch  520/538 - Train Accuracy:  0.937, Validation Accuracy:  0.923, Loss:  0.047
# Epoch   2 Batch  521/538 - Train Accuracy:  0.929, Validation Accuracy:  0.924, Loss:  0.066
# Epoch   2 Batch  522/538 - Train Accuracy:  0.924, Validation Accuracy:  0.926, Loss:  0.046
# Epoch   2 Batch  523/538 - Train Accuracy:  0.937, Validation Accuracy:  0.927, Loss:  0.047
# Epoch   2 Batch  524/538 - Train Accuracy:  0.928, Validation Accuracy:  0.928, Loss:  0.050
# Epoch   2 Batch  525/538 - Train Accuracy:  0.932, Validation Accuracy:  0.932, Loss:  0.051
# Epoch   2 Batch  526/538 - Train Accuracy:  0.928, Validation Accuracy:  0.926, Loss:  0.048
# Epoch   2 Batch  527/538 - Train Accuracy:  0.939, Validation Accuracy:  0.928, Loss:  0.050
# Epoch   2 Batch  528/538 - Train Accuracy:  0.918, Validation Accuracy:  0.931, Loss:  0.056
# Epoch   2 Batch  529/538 - Train Accuracy:  0.905, Validation Accuracy:  0.927, Loss:  0.050
# Epoch   2 Batch  530/538 - Train Accuracy:  0.911, Validation Accuracy:  0.928, Loss:  0.057
# Epoch   2 Batch  531/538 - Train Accuracy:  0.927, Validation Accuracy:  0.929, Loss:  0.055
# Epoch   2 Batch  532/538 - Train Accuracy:  0.928, Validation Accuracy:  0.929, Loss:  0.044
# Epoch   2 Batch  533/538 - Train Accuracy:  0.933, Validation Accuracy:  0.933, Loss:  0.056
# Epoch   2 Batch  534/538 - Train Accuracy:  0.939, Validation Accuracy:  0.928, Loss:  0.040
# Epoch   2 Batch  535/538 - Train Accuracy:  0.932, Validation Accuracy:  0.931, Loss:  0.046
# Epoch   2 Batch  536/538 - Train Accuracy:  0.934, Validation Accuracy:  0.925, Loss:  0.058
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
# Save parameters for checkpoint
pickle.dump(save_path, open('params.p', 'wb'))

# %% [markdown]
# # Checkpoint

# %%
import tensorflow as tf
import numpy as np
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = pickle.load(open('preprocess.p', mode='rb'))
load_path = pickle.load(open('params.p', mode='rb'))

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    sentence = sentence.lower()
    
    output = []
    
    for token in sentence.split(' '):
        if (token in vocab_to_int):
            output.append(vocab_to_int[token])
        else:
            output.append(vocab_to_int['<UNK>'])
    
    return output

tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'

translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [136, 157, 103, 34, 63, 156, 188]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [129, 220, 346, 305, 338, 102, 165, 1]
#   French Words: ['il', 'a', 'vu', 'au', 'automobile', 'jaune', '.', '<EOS>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
